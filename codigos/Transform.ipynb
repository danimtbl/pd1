# %%
#imports necessários
from pyspark.sql.types import *
from pyspark.sql.functions import *
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession

# %%
format = 'parquet'
inferSchema = 'false'
header = 'false'
multiline = 'false'

# %%
#Configurando spark
conf = SparkConf().setAppName('Load').set("spark.serializer", "org.apache.spark.serializer.KryoSerializer").set("hive.exec.dynamic.partition", "true").set("hive.exec.dynamic.partition.mode", "nonstrict")
spark = SparkSession.builder.config(conf=conf).enableHiveSupport().getOrCreate()

# %%
#Definindo caminho de arquivos parquet do raw_data para fazer as transformações necessárias
filePath1 = 'C:\\Users\\dbello\Documents\\pd-desafio\\raw_data\\students\\*.parquet'
filePath2 = 'C:\\Users\\dbello\Documents\\pd-desafio\\raw_data\\courses\\*.parquet'
filePath3 = 'C:\\Users\\dbello\Documents\\pd-desafio\\raw_data\\subjects\\*.parquet'
filePath4 = 'C:\\Users\\dbello\Documents\\pd-desafio\\raw_data\\universities\\*.parquet'
filePath5 = 'C:\\Users\\dbello\Documents\\pd-desafio\\raw_data\\subscriptions\\*.parquet'
filePath6 = 'C:\\Users\\dbello\Documents\\pd-desafio\\raw_data\\sessions\\*.parquet'
filePath7 = 'C:\\Users\\dbello\Documents\\pd-desafio\\raw_data\\student_follow_subject\\*.parquet'

# %%
#Lendo para dfs
df_students = spark.read.format(format) \
                    .option("inferSchema", inferSchema) \
                    .option("header", header) \
                    .option("multiLine", multiline) \
                    .parquet(filePath1)
df_courses = spark.read.format(format) \
                    .option("inferSchema", inferSchema) \
                    .option("header", header) \
                    .option("multiLine", multiline) \
                    .parquet(filePath2)
df_subjects = spark.read.format(format) \
                    .option("inferSchema", inferSchema) \
                    .option("header", header) \
                    .option("multiLine", multiline) \
                    .parquet(filePath3)
df_universities = spark.read.format(format) \
                    .option("inferSchema", inferSchema) \
                    .option("header", header) \
                    .option("multiLine", multiline) \
                    .parquet(filePath4)
df_subscriptions = spark.read.format(format) \
                    .option("inferSchema", inferSchema) \
                    .option("header", header) \
                    .option("multiLine", multiline) \
                    .parquet(filePath5)
df_sessions = spark.read.format(format) \
                    .option("inferSchema", inferSchema) \
                    .option("header", header) \
                    .option("multiLine", multiline) \
                    .parquet(filePath6)
df_student_follow_subject = spark.read.format(format) \
                    .option("inferSchema", inferSchema) \
                    .option("header", header) \
                    .option("multiLine", multiline) \
                    .parquet(filePath7)

# %%
#Criando um df parcial para receber o join entre curso e estudante, tirando o id duplicado de curso e renomeando a coluna de nome de matéria para não ficar confuso
df_parcial = df_students.join(df_courses,df_students.CourseId == df_courses.Id, how='left').drop(df_courses.Id).drop(df_students.CourseId).withColumnRenamed("Name", "CourseName")

# %%
#Join entre parcial e universidade para incluir o nome da universidade 
df_parcial2 = df_parcial.join(df_universities, df_parcial.UniversityId == df_universities.Id, how='left').drop(df_universities.Id).drop(df_parcial.UniversityId).withColumnRenamed("Name", "UniversityName").withColumnRenamed("StudentClient", "StudentClientSignUp")

# %%
#Join com subscripiton para incluir tipo de plano e data de pagamento
df_parcial3 = df_parcial2.join(df_subscriptions, df_parcial2.Id == df_subscriptions.StudentId, how='leftouter').drop(df_subscriptions.StudentId)

# %%
#2 registros a mais
df_parcial3.count()
# Out:
# 60002

# %%
#Agregando por Id para descobrir qual id esta duplicado
df = df_parcial3.groupBy("Id").agg(count("Id"))

# %%
#pegando os Ids duplicados para analisar
df = df.withColumnRenamed("count(Id)", "count")
df.filter("count > 1").collect()
# Out:
# [Row(Id='308a29d8d37388ed84b6b1930bf084f50249c15c244df26a3491ed5751917af2', count=2),
#  Row(Id='7b63067f9475c2e824608e412d1014e289997f9730cf918e975237136104016e', count=2)]

# %%
#2 datas de pagamento
df_parcial3.select(col('*')).filter(df_parcial3.Id == "7b63067f9475c2e824608e412d1014e289997f9730cf918e975237136104016e").toPandas()
# Out:
#              City                                                 Id  \
# 0  Rio de Janeiro  7b63067f9475c2e824608e412d1014e289997f9730cf91...
# 1  Rio de Janeiro  7b63067f9475c2e824608e412d1014e289997f9730cf91...
#
#                RegisteredDate SignupSource           State  \
# 0  2017-04-07 09:26:36.423000     Facebook  Rio de Janeiro
# 1  2017-04-07 09:26:36.423000     Facebook  Rio de Janeiro
#
#   StudentClientSignUp            CourseName UniversityName  \
# 0                None  Processos Gerenciais    ESTÁCIO EAD
# 1                None  Processos Gerenciais    ESTÁCIO EAD
#
#                   PaymentDate PlanType
# 0  2017-11-30 08:34:57.729857   Mensal
# 1  2017-11-01 00:30:50.515472   Mensal

# %%
#join entre parcial e matérias seguidas
df_parcial4 = df_parcial3.join(df_student_follow_subject, df_parcial3.Id == df_student_follow_subject.StudentId, how='left').drop(df_student_follow_subject.StudentId)

# %%
#join com o df de matérias para deixar incluir o nome da matéria seguida
df_parcial5 = df_parcial4.join(df_subjects, df_parcial4.SubjectId == df_subjects.Id, how='left').drop(df_subjects.Id).drop(df_parcial4.SubjectId).withColumnRenamed("Name", "SubjectName")

# %%
#join com df de sessão
df_final = df_parcial5.join(df_sessions, df_parcial5.Id == df_sessions.StudentId, how='left').drop(df_sessions.StudentId).withColumnRenamed("StudentClient", "StudentClientSession")

# %%
df_final.agg(countDistinct("Id")).show()
# Out:
# +------------------+
# |count(DISTINCT Id)|
# +------------------+
# |             60000|
# +------------------+

# %%
df_final.printSchema()
# Out:
# root
#  |-- City: string (nullable = true)
#  |-- Id: string (nullable = true)
#  |-- RegisteredDate: string (nullable = true)
#  |-- SignupSource: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- StudentClientSignUp: string (nullable = true)
#  |-- CourseName: string (nullable = true)
#  |-- UniversityName: string (nullable = true)
#  |-- PaymentDate: string (nullable = true)
#  |-- PlanType: string (nullable = true)
#  |-- FollowDate: string (nullable = true)
#  |-- SubjectName: string (nullable = true)
#  |-- SessionStartTime: string (nullable = true)
#  |-- StudentClientSession: string (nullable = true)

# %%
#Visão de quantos alunos seguem cada matéria 
df = df_final.groupBy("SubjectName").agg(countDistinct("Id")).orderBy('count(DISTINCT Id)').show(n =20580)
# Out:
# +--------------------+------------------+
# |         SubjectName|count(DISTINCT Id)|
# +--------------------+------------------+
# |Desenvolvimento e...|                 1|
# |   Agrossilvicultura|                 1|
# |Educação Infantil...|                 1|
# |Qual É A Resposta...|                 1|
# |    Recursos Manuais|                 1|
# |Ciência e Poluiçã...|                 1|
# |Estrutura e Dinâm...|                 1|
# |Política Educacio...|                 1|
# |Análise do Transp...|                 1|
# |Teoria Política C...|                 1|
# |Governança e Plan...|                 1|
# |Matemática e Esta...|                 1|
# |   Pratica de Textos|                 1|
# |Organização e Ava...|                 1|
# |Microbiologia e S...|                 1|
# |Gestao de Projeto...|                 1|
# |Modelagem de Info...|                 1|
# |Agressão, Defesa,...|                 1|
# |Fundamentos e Mét...|                 1|
# |      Tópicos Esp. C|                 1|
# |Socioantropologia...|                 1|
# |Ginástica Geral e...|                 1|
# |       Noção Atuaria|                 1|
# |Estudo de Caso - ...|                 1|
# |Técnicas de Entre...|                 1|
# |            O Estado|                 1|
# |Farmácia Clínica ...|                 1|
# |Servico Social Di...|                 1|
# |   Culturas de Verão|                 1|
# |Fisiologia Humana...|                 1|
# |Experimentação no...|                 1|
# |Anatomia Estrutur...|                 1|
# |Ética, Cidadania ...|                 1|
# |Cooperação Intern...|                 1|
# |Filosofia e Ciênc...|                 1|
# |Recursos e Tecnol...|                 1|
# |Gestão e Ciência ...|                 1|
# |Legislação Ambien...|                 1|
# |                Peça|                 1|
# |Pesquisa com Alim...|                 1|
# | Cultura e Ideologia|                 1|
# |Elementos do Proc...|                 1|
# |           Joguinhos|                 1|
# |                   T|                 1|
# |Contabilidade e C...|                 1|
# |Entrevista e Obse...|                 1|
# |Procedimentos Penais|                 1|
# |Fund Mult da His ...|                 1|
# |Formação de Preço...|                 1|
# |Sistema Geográfic...|                 1|
# |Políticas e Gestã...|                 1|
# |Desenvolvimento R...|                 1|
# |Oficina de Experi...|                 1|
# |Fundamentos Fenom...|                 1|
# |    Taxa Equivalente|                 1|
# |Cibercultura e Pr...|                 1|
# |Fisiologia Compar...|                 1|
# |Top Contemp em Co...|                 1|
# |Laboratório de Re...|                 1|
# |Atividade Gestão ...|                 1|
# |Oficina de Comuni...|                 1|
# |     Banco de Sangue|                 1|
# |Literatura e Form...|                 1|
# |  Teoria Sociológica|                 1|
# |Recreação e Lazer...|                 1|
# |Como Passar no Ex...|                 1|
# |Mecanica Newtonia...|                 1|
# |Curso: O Cristão ...|                 1|
# |Ética e Filosofia...|                 1|
# |  Projeto II - Civil|                 1|
# |Etnologia e Etnic...|                 1|
# |Resolução Cálculo...|                 1|
# |Tenho 7 Semestre ...|                 1|
# |Antropologia e So...|                 1|
# | Redes de Cooperação|                 1|
# |Usuarios da Infor...|                 1|
# |  Várias Disciplinas|                 1|
# |Direito da Reform...|                 1|
# |Nutrição Aplicada...|                 1|
# |Citologia Veterin...|                 1|
# |Genética e Imunol...|                 1|
# |Fisiologia e Bioq...|                 1|
# |Teoria da Gestão ...|                 1|
# |          Organica 3|                 1|
# |Direito Societario I|                 1|
# |Sistemas Estrutur...|                 1|
# |Epistemologia Geo...|                 1|
# |Gerenciamento de ...|                 1|
# |Tecnologia de Óle...|                 1|
# | Comunicação e Ética|                 1|
# |Cidades, Culturas...|                 1|
# |Teoria dos Jogos ...|                 1|
# |Fotônica Computac...|                 1|
# |História do Livro...|                 1|
# | Design e Estetica R|                 1|
# |Fluidos, Oscilaçõ...|                 1|
# |Estu Gram Port Co...|                 1|
# |História Antiga A...|                 1|
# |            Pinesc I|                 1|
# |Cidade e Poder Local|                 1|
# |     Conversao Ad-da|                 1|
# |Psicologia e Antr...|                 1|
# | Campanha de Produto|                 1|
# |Spas e Terapias A...|                 1|
# |Introdução à Geof...|                 1|
# |Contabilidade par...|                 1|
# |Fundamentos de Hi...|                 1|
# |Vestibular Uema-paes|                 1|
# |Percepção, Estéti...|                 1|
# |Ciência Política ...|                 1|
# |            Sinopses|                 1|
# |Técnicas de Apura...|                 1|
# |Decisões Multicri...|                 1|
# |                 Crm|                 1|
# |               Bower|                 1|
# |Leituras de Émile...|                 1|
# |Fenômenos de Tran...|                 1|
# |Ciência dos Mater...|                 1|
# |Processos Químico...|                 1|
# |Fisiologia do Exe...|                 1|
# |Parametros Curric...|                 1|
# |Ensino Social e C...|                 1|
# |Economia Aplicada...|                 1|
# |Competências Básicas|                 1|
# |Política e Legisl...|                 1|
# | Literatura Cearense|                 1|
# |     Est Aplicada 10|                 1|
# |Consentimentos Mi...|                 1|
# |Contabilidade Are...|                 1|
# |Práticas do Cuidar I|                 1|
# |Prog-produto em E...|                 1|
# |Conceitos de Astr...|                 1|
# |Industrialização ...|                 1|
# |Metabolismo e Reg...|                 1|
# |Piscicologia do D...|                 1|
# |   Projeto Urbano II|                 1|
# |Recursos Humanos ...|                 1|
# |Controle da Admin...|                 1|
# |Psicologia da Ado...|                 1|
# |Andragogia e Educ...|                 1|
# |Topicos em Contab...|                 1|
# |Metodologia da Pe...|                 1|
# |Enfermagem no Con...|                 1|
# |Metodologia e Lóg...|                 1|
# |Juizados Especiai...|                 1|
# |      Workshop Geral|                 1|
# |Doenças Bacterian...|                 1|
# |    Literatura Surda|                 1|
# |Bases Semiológica...|                 1|
# |     Prática Forense|                 1|
# |Citologia e Morfo...|                 1|
# |Planejamento de M...|                 1|
# |  Estado e Sociedade|                 1|
# |Tópico Especial P...|                 1|
# |Gestão de Conflit...|                 1|
# |Pesquisa Quantita...|                 1|
# |Mineralogia e Pet...|                 1|
# |Morfofisiologia H...|                 1|
# |Elementos Técnico...|                 1|
# |Biologia de Vírus...|                 1|
# |Chapas Metálicas ...|                 1|
# |Comunicação e Uni...|                 1|
# |Direito dos Segur...|                 1|
# |Estruturas Comple...|                 1|
# |Física Experiment...|                 1|
# |Geocronologia e G...|                 1|
# |Anatomia Topográf...|                 1|
# |Familia Contempor...|                 1|
# |Canais de Distrib...|                 1|
# |Planos de Aula Ed...|                 1|
# |Estágio Supervisi...|                 1|
# |Legislação e Dire...|                 1|
# |Lab. Controle Dig...|                 1|
# |Ciências Sociais ...|                 1|
# |Tópicos Especiais...|                 1|
# |Leitura, Interpre...|                 1|
# |Sistema de Gestão...|                 1|
# |Interpretação S S...|                 1|
# |Políticas de Saúd...|                 1|
# |Erros Inatos do M...|                 1|
# |Normas da Correge...|                 1|
# |Práticas em Biome...|                 1|
# |                Iddp|                 1|
# |Html5, Css3, Java...|                 1|
# |         Patologia 3|                 1|
# |Fundamentos da Co...|                 1|
# |Princípios de Tel...|                 1|
# |   Violencia e Saude|                 1|
# |     Prática Docente|                 1|
# | Etologia Zootécnica|                 1|
# |Biossegurança em ...|                 1|
# |Comercio Internac...|                 1|
# |Met.prat.de Alfab...|                 1|
# |Ética e Mídia na ...|                 1|
# |Inovação Tecnológ...|                 1|
# |Progama de Prátic...|                 1|
# |Relações Internac...|                 1|
# |Planejamento Urba...|                 1|
# |Introdução à Biot...|                 1|
# |Ingles Ii: Lingua...|                 1|
# |Tecnologia Constr...|                 1|
# |Neuropsicopedagog...|                 1|
# |               Dicas|                 1|
# |Instrumentação, C...|                 1|
# | Estágio em Farmácia|                 1|
# |Direito da Seguri...|                 1|
# |Espanhol Aspectos...|                 1|
# |Estudos do Movime...|                 1|
# |Processo Internac...|                 1|
# |    Psicolinguistica|                 1|
# |             Bebidas|                 1|
# |Informática Jurídica|                 1|
# |Estudos do Capita...|                 1|
# |Projeto em Comuni...|                 1|
# |Mecanica de Rocha...|                 1|
# |           3 Periodo|                 1|
# |Barragens e Estru...|                 1|
# |Modelagem de Carg...|                 1|
# |Gerenciamento Est...|                 1|
# |Gestão e Mapeamen...|                 1|
# |              Laudos|                 1|
# |  Álgebra Comutativa|                 1|
# |Teoria e Prática ...|                 1|
# |              Hcafro|                 1|
# |Administração e P...|                 1|
# |Ética e Gestão Só...|                 1|
# |Teoria e Sistemas...|                 1|
# |Luminotécnica Apl...|                 1|
# | Projeto Empresarial|                 1|
# |Fundamentos e Téc...|                 1|
# |Direitos Humanos ...|                 1|
# |Situação de Saúde...|                 1|
# |Prova Oral de Dir...|                 1|
# |Brasil: Cenário S...|                 1|
# |(tj/pa) no Que Ta...|                 1|
# |Prát Tra Ing-port...|                 1|
# |               Cespe|                 1|
# |Anatomia Clínica ...|                 1|
# |Desmonte de Rocha...|                 1|
# |Aptidão Agrícola ...|                 1|
# |Auditoria, Certif...|                 1|
# |Estruturas de Lin...|                 1|
# |Direito do Trabal...|                 1|
# |Estudos Isciplina...|                 1|
# |  Sistema Urogenital|                 1|
# |Contabilidade - A...|                 1|
# |  Desafio 4 Semestre|                 1|
# |Formulações de Di...|                 1|
# |Redes e Protocolo...|                 1|
# |                 Bhe|                 1|
# |Avaliação Virtual...|                 1|
# |Atenção e Gerênci...|                 1|
# |Etnia, Gênero e A...|                 1|
# |Materiais e Corrosão|                 1|
# |Estágio II - A (p...|                 1|
# | Aspecto Fundamental|                 1|
# |Topicos Comportam...|                 1|
# |Aditivos e Coadju...|                 1|
# |Relações Humanas ...|                 1|
# |Gênese e Classifi...|                 1|
# |         Patologia 4|                 1|
# | Exames  Citológicos|                 1|
# |Princípios de Com...|                 1|
# |Psicologia e Comp...|                 1|
# |Bases  Sociológic...|                 1|
# |Diversidade Animal I|                 1|
# |Aquisição e Desen...|                 1|
# |        Elementos de|                 1|
# |Abordagens Fenom....|                 1|
# |Alfabetização e L...|                 1|
# | Comunicação Digital|                 1|
# |Gestão e Planejam...|                 1|
# |Supervisão Pedagó...|                 1|
# |Gerenciamento e G...|                 1|
# |Cirurgia de Cabeç...|                 1|
# |Gest de Equipes d...|                 1|
# |Enferm Cuidados C...|                 1|
# |Gestão de Ambient...|                 1|
# |Políticas Pública...|                 1|
# |   Cor e Comunicação|                 1|
# |História da Socio...|                 1|
# |Elaboração de Res...|                 1|
# |Currículo e Progr...|                 1|
# |Relação Entre Esc...|                 1|
# |Cartografia e Geo...|                 1|
# |   Doutrina Juridica|                 1|
# |    Mídia e Religião|                 1|
# |Avaliação e Reten...|                 1|
# |Contabilidade Fin...|                 1|
# |Circuito Hid e Pn...|                 1|
# |Psicologia Aplica...|                 1|
# |Teoria Geral do P...|                 1|
# |Base de Gestão em...|                 1|
# |Comunicação e Rea...|                 1|
# |Aspectos da Lingu...|                 1|
# |       Folha Pautada|                 1|
# |Teoria da Históri...|                 1|
# |Linguagem Jurídic...|                 1|
# |Práticas de Hidrá...|                 1|
# |Cadeia Produtiva ...|                 1|
# |Avaliacao de Obri...|                 1|
# |Redes Sociais e C...|                 1|
# |Fisiologia da Lac...|                 1|
# |Metodologia da  A...|                 1|
# |Gráfica da Figura...|                 1|
# |Organização e Man...|                 1|
# |Mecatronica Indus...|                 1|
# |Gestão de Recurso...|                 1|
# |Laboratório de Té...|                 1|
# |Planejamento, Ges...|                 1|
# |Gestão e Fiscaliz...|                 1|
# |Direito nas Organ...|                 1|
# |Estágio Supervisi...|                 1|
# |Desenvolvimento R...|                 1|
# |       Jacques Lacan|                 1|
# |Administração e P...|                 1|
# |Engenharia de Pol...|                 1|
# |Fundamentos da Ga...|                 1|
# |Língua Portuguêsa...|                 1|
# |Estudos Lógicos M...|                 1|
# |Anatomia da Colun...|                 1|
# |Comportamento, Cl...|                 1|
# |Tóp. Esp. em Antr...|                 1|
# |Fundamentos de El...|                 1|
# |Redação e Relatór...|                 1|
# |Metodologia Cient...|                 1|
# |Estudos Discilpin...|                 1|
# |Eletrocardiografi...|                 1|
# |Biofísica para Ve...|                 1|
# |Conceitos e Funda...|                 1|
# |Logística Empresa...|                 1|
# |Implementação e T...|                 1|
# |Morfologia de Alg...|                 1|
# |Serraria e Secage...|                 1|
# |Administração e M...|                 1|
# |Estrutura e Func....|                 1|
# |Estudos Disciplin...|                 1|
# |               Admii|                 1|
# |História da Educa...|                 1|
# |História do Brasi...|                 1|
# |Estrutura e Funçã...|                 1|
# |Clt - Direto do T...|                 1|
# |Planejamento e Op...|                 1|
# |Gestão de Sistema...|                 1|
# |Microeconomia da ...|                 1|
# |                 Rlm|                 1|
# |Preservacao de Re...|                 1|
# |Gênero Cinematogr...|                 1|
# |Meio Ambiente e D...|                 1|
# |Logica para Programa|                 1|
# |Linguagem Audiovi...|                 1|
# |Desenho de Repres...|                 1|
# |Problemas Fundame...|                 1|
# |Levantamento de C...|                 1|
# |Analise de Sistem...|                 1|
# |Gestao Integrada ...|                 1|
# |Fsiologia Animal ...|                 1|
# |Economia Neoclass...|                 1|
# |Educação Física, ...|                 1|
# |Administração e O...|                 1|
# |   Estatística Geral|                 1|
# |Estética - Artes ...|                 1|
# |Teoria de Língua ...|                 1|
# |     Laboratorio III|                 1|
# |Seminários em Adm...|                 1|
# |Direito Penal- Cr...|                 1|
# |Formação de Preço...|                 1|
# |Espaço Geográfico...|                 1|
# |Operac. e Sistema...|                 1|
# |Bases Filosóficas...|                 1|
# |Antropologia e So...|                 1|
# |Laboratório de En...|                 1|
# |Empreendedorismo ...|                 1|
# |Fontes das Obriga...|                 1|
# |Inspecao de Carne...|                 1|
# |Administracao Fam...|                 1|
# |Métodos de Preç...|                 1|
# |Projeto de Sistem...|                 1|
# |Curso de Direito ...|                 1|
# |Informática Aplic...|                 1|
# |Anatomia Palpatór...|                 1|
# |Estudos Sobre A I...|                 1|
# |Cidadania e Respo...|                 1|
# |Apostila - Portug...|                 1|
# |Qui Organ P/ Cien...|                 1|
# |Terapia Cognitivo...|                 1|
# |               Canto|                 1|
# |Teoria da Comunic...|                 1|
# |Tópicos em Histór...|                 1|
# |Metodologia de Pe...|                 1|
# |                Admk|                 1|
# |Organizacao Polít...|                 1|
# |                 Erp|                 1|
# |        Ética e Gest|                 1|
# |Gestão de Talento...|                 1|
# |Aritmética dos In...|                 1|
# |Análise e Modelag...|                 1|
# |Seminário Interdi...|                 1|
# |Teoria e Técnica ...|                 1|
# |  Plantas Medicinais|                 1|
# |  Composição da Água|                 1|
# |Empreendedorismo ...|                 1|
# |   História e Ensino|                 1|
# |Introdução A Enge...|                 1|
# |Recursos e Habili...|                 1|
# |Escrituração Cont...|                 1|
# |Termodinâmica e F...|                 1|
# |Bas Morf Bio Apli...|                 1|
# |Gestão e Responsa...|                 1|
# |Fisiologia Aplica...|                 1|
# |Sociologia da Ciê...|                 1|
# |   Estudos para Enem|                 1|
# |Prática Educativa...|                 1|
# |Mecânica Aplicada...|                 1|
# |Cinema, Literatur...|                 1|
# |Sistematica de Pl...|                 1|
# | Direito Cooperativo|                 1|
# |Genética Básica e...|                 1|
# |Projetos Mecânicos I|                 1|
# |Fisiologia e Biot...|                 1|
# |          Estrutural|                 1|
# |Teoria Geral da A...|                 1|
# |Produção de Event...|                 1|
# |Estágio Supervisi...|                 1|
# |     Design Branding|                 1|
# |Planejamento de S...|                 1|
# |Planejamento Estr...|                 1|
# |Prática de Extens...|                 1|
# |Seminario II - At...|                 1|
# |Fonoaudiologia, S...|                 1|
# |Barragem “reserv...|                 1|
# |Fundamentos de En...|                 1|
# |Recuperação da In...|                 1|
# |Introdução ao Des...|                 1|
# |Projeto de Editor...|                 1|
# |Desenho e Projeto...|                 1|
# |Teorias e Sistemas I|                 1|
# |Processos Gerais ...|                 1|
# |Direito Comunitár...|                 1|
# |Estruturas de Fun...|                 1|
# |Biologia de Bacte...|                 1|
# |Arborizacao e Pai...|                 1|
# |             Fis 201|                 1|
# |Determinantes Soc...|                 1|
# |Tópicos Esp. em P...|                 1|
# |   Matematica Finita|                 1|
# |Odontologia em Sa...|                 1|
# |Instrumentos e Mé...|                 1|
# |Psic da Educ(evol...|                 1|
# |Calculo Diferenci...|                 1|
# |  História da Guerra|                 1|
# | Culinaria e Turismo|                 1|
# |  Desenho Estrutural|                 1|
# |Governação Eleitoral|                 1|
# |Fisioterapia em E...|                 1|
# |Agrimensura Aplicada|                 1|
# | Criação e Percepção|                 1|
# |           Cuidar  3|                 1|
# |Toas As Disciplin...|                 1|
# |    Geologia Mineral|                 1|
# |Aplicações de Mod...|                 1|
# |Complemento Mecan...|                 1|
# |Fundamentos Juríd...|                 1|
# |Ética e O Exercíc...|                 1|
# |      Tese Doutorado|                 1|
# |Procedimentos e P...|                 1|
# |   Geografia Uninter|                 1|
# |Sinais, Sistemas ...|                 1|
# |Relações Étnico-r...|                 1|
# |Analise de Crédit...|                 1|
# |Esporte, Lazer e ...|                 1|
# |Políticas e Práti...|                 1|
# |Medidas Elétricas...|                 1|
# |Instalaçoes Eletr...|                 1|
# |Aprendizagem Gene...|                 1|
# |Transportes Publi...|                 1|
# |             Pim VII|                 1|
# |Supervisao Educac...|                 1|
# |   Desenho Universal|                 1|
# |Gestão de Negócio...|                 1|
# |Estudos Disciplin...|                 1|
# |  Orientação Escolar|                 1|
# |Fundamentos do Tr...|                 1|
# |Ensino de Língua ...|                 1|
# |   Física Básica III|                 1|
# |Atividades Curric...|                 1|
# |Psicoterapia Huma...|                 1|
# |     Europa Medieval|                 1|
# |Psicologia Analít...|                 1|
# | Práticas de Roteiro|                 1|
# |        Microecnomia|                 1|
# |Aprendizagem e Mo...|                 1|
# |   Fundacoes e Obras|                 1|
# |Séries de Equaçõe...|                 1|
# |Urbanismo e Paisa...|                 1|
# |Teoria da Históri...|                 1|
# | Tecnologia Orgânica|                 1|
# |Circuitos Eletrôn...|                 1|
# |Biotecnologia em ...|                 1|
# |          Oficinas A|                 1|
# |Antropologia, Psc...|                 1|
# |Imunologia Aplica...|                 1|
# |Materiais de Cons...|                 1|
# |Ciência dos Alime...|                 1|
# |Legislação Trabal...|                 1|
# |Bioética em Biologia|                 1|
# |Garantia e Contro...|                 1|
# |Contabilidade de ...|                 1|
# |Análise Linear de...|                 1|
# |Direito Civil IV ...|                 1|
# |Ges de Proj de Ar...|                 1|
# |<strong>mediação ...|                 1|
# |Psicopatologia Ge...|                 1|
# |Antropologia e So...|                 1|
# |Planejamento Urba...|                 1|
# |Tópico de Lietart...|                 1|
# |             Norma A|                 1|
# |   Leite e Derivados|                 1|
# | Tópicos Especiais e|                 1|
# |Concepcao e Gestacao|                 1|
# |Como São Classifi...|                 1|
# |   Teoria de Vôo III|                 1|
# |     Tendência em Rh|                 1|
# |Promotor Justiça ...|                 1|
# |Estudos Avançados...|                 1|
# |Escola Austríaca ...|                 1|
# |Tecnologia e Indu...|                 1|
# |  Gestão Tecnológica|                 1|
# |Gerenciamento de ...|                 1|
# |Seminário em Gest...|                 1|
# |Ferramentas para ...|                 1|
# |     Processo Grupal|                 1|
# |Engenharia de Rec...|                 1|
# |Saúde Mental e At...|                 1|
# | Métodos Geoquímicos|                 1|
# |Economia Rural e ...|                 1|
# |Memória, Historio...|                 1|
# |Princípios de Adm...|                 1|
# | Integracao Regional|                 1|
# |      Educação Inclu|                 1|
# |Bncc e A Educação...|                 1|
# |Fundamentos de Co...|                 1|
# |      Teste Wisciiii|                 1|
# |    Manejo de Pragas|                 1|
# |2ª Ciências Odont...|                 1|
# |  Agroecossistemas I|                 1|
# |Globalização e Te...|                 1|
# |     Mente e Cérebro|                 1|
# |Introdução As Cie...|                 1|
# |Estágio Supervisi...|                 1|
# |     Nutricao Social|                 1|
# |   Análise de Sinais|                 1|
# |Desenvolvimento d...|                 1|
# |Introdução ao Rac...|                 1|
# |Dinâmicas da Trib...|                 1|
# | Executivo de Contas|                 1|
# |  Cidade e Habitação|                 1|
# |Atenção Primária ...|                 1|
# |Máquinas Hidráuli...|                 1|
# |Sensoriamento Rem...|                 1|
# |Neuropsicofisiologia|                 1|
# |Atividades Acadêm...|                 1|
# |                Iere|                 1|
# |Metodos de Estudo...|                 1|
# |Projeto do Trabal...|                 1|
# |  Embriologia Animal|                 1|
# |Organizaçao do Tr...|                 1|
# |História da Arte ...|                 1|
# |Gestão de Desempe...|                 1|
# |Participacao em E...|                 1|
# | Saúde da Criança no|                 1|
# |  Espacos Metricos I|                 1|
# |Prática em Quirop...|                 1|
# |  Editoração Gráfica|                 1|
# |Organização e Adm...|                 1|
# | Física I, Ii, Iii,i|                 1|
# |Jornalismo e Cult...|                 1|
# |Auditoria Sis Com...|                 1|
# |Estatistica Avg U...|                 1|
# |Teologia e Ciênci...|                 1|
# |Comunicação e Rel...|                 1|
# |Metalurgia dos Fe...|                 1|
# |Patologia dos Pro...|                 1|
# |Termodinâmica Quí...|                 1|
# |Práticas em Biome...|                 1|
# |                Flex|                 1|
# |Introducao A Inte...|                 1|
# |Criação e Gerenci...|                 1|
# |     Conectividade 2|                 1|
# |Psicoterapia Comp...|                 1|
# |Geoquímica do Pet...|                 1|
# |Desenho de Observ...|                 1|
# |Zoonoses e Saúde ...|                 1|
# |Enfermagem na Ass...|                 1|
# |Clínica da Infânc...|                 1|
# |Nutrição em Ativi...|                 1|
# |       Lit Hisp-amer|                 1|
# | Componente do P.e.a|                 1|
# |Mapeamento Gerenc...|                 1|
# |Estudos Organizac...|                 1|
# |Hidráulica, Hidro...|                 1|
# |Dignidade da Pess...|                 1|
# |Tcc em Gestão de ...|                 1|
# |Enfermagem Neo-natal|                 1|
# |Planejamento de E...|                 1|
# |Desenvolvimento R...|                 1|
# |Cartografia e Geo...|                 1|
# |Enfermagem de Eme...|                 1|
# |Relatorio de Pesq...|                 1|
# |Visão Sistêmica e...|                 1|
# |          Pa Gravura|                 1|
# |   Produção Mecânica|                 1|
# |Estágio Supervisi...|                 1|
# |Morfologia e Clas...|                 1|
# |Metodologia da Pe...|                 1|
# |Materiais e Técni...|                 1|
# |Estruturas de Mad...|                 1|
# |  Farmacoterapêutica|                 1|
# |             Revisão|                 1|
# |Grandes Culturas ...|                 1|
# | Educação e Surdez I|                 1|
# |Linguagem de Prog...|                 1|
# |Praticas em Negoc...|                 1|
# |Introdução à Econ...|                 1|
# |           Fonologia|                 1|
# |Testes Psicológic...|                 1|
# |Introd. A Pesq. O...|                 1|
# |Sistemas de Infor...|                 1|
# |Diagnóstico Patol...|                 1|
# |Etica Empresarial...|                 1|
# |Gestão Estratégic...|                 1|
# |Gabarito do Curso...|                 1|
# |Gestão e Planejam...|                 1|
# |Ótica, Ondas e El...|                 1|
# |Contabilidade Fin...|                 1|
# |Indivíduos, Grupo...|                 1|
# |                 Icc|                 1|
# |Educação Especial...|                 1|
# |Clinica Cirurgica...|                 1|
# |Física Aplicada à...|                 1|
# |Língua Portuguesa...|                 1|
# |Alimentação e Nut...|                 1|
# |Tópicos Especiais...|                 1|
# |Sistemas Articulados|                 1|
# |Estudos Liter. Iv...|                 1|
# |Governança de Seg...|                 1|
# |Top.avanc. Matema...|                 1|
# |Fisioterapia Resp...|                 1|
# |Investigaçao I- C...|                 1|
# |Estudo dos Clássicos|                 1|
# |Estagio Obrigator...|                 1|
# | Psicologia na Saúde|                 1|
# |História e Evoluç...|                 1|
# |Direito Empresari...|                 1|
# |Estágio Supervisi...|                 1|
# |    Solos Florestais|                 1|
# |Geometria / Prog....|                 1|
# |Direito Penal II ...|                 1|
# |Comunicação e Ext...|                 1|
# |Habilidades Espec...|                 1|
# |Manutenção Preditiva|                 1|
# |Sociedade, Nature...|                 1|
# |Microrganismos e ...|                 1|
# |Fundamentos Histó...|                 1|
# |          Benefícios|                 1|
# |Materiais e Recic...|                 1|
# |Matemática na Edu...|                 1|
# |              Sadsad|                 1|
# | Ecologia e Poluição|                 1|
# |Técnica de Report...|                 1|
# |Administração de ...|                 1|
# |                 Fgv|                 1|
# |Gasto Energético-...|                 1|
# |Estágio I – Saúde...|                 1|
# |Topicos de Atuaçã...|                 1|
# |Lit Bras - Barroc...|                 1|
# |Gramática Normati...|                 1|
# |Estatistica Univa...|                 1|
# |Planos, Programas...|                 1|
# |Físico- Química G...|                 1|
# |Programação de Sc...|                 1|
# |Economia e Financ...|                 1|
# |Fundamento do Der...|                 1|
# |Segundo Piaget, p...|                 1|
# |Mercado de Deriva...|                 1|
# |Legislação Tribut...|                 1|
# |Tópicos Especiais...|                 1|
# |Laboratório de Pr...|                 1|
# |  Geografia de Goiás|                 1|
# |Sistema de Transp...|                 1|
# |Botânica Aplicada...|                 1|
# |Doencas Causadas ...|                 1|
# |Geofísica de Petr...|                 1|
# |              Of III|                 1|
# |Laboratório Ensin...|                 1|
# |Educação Patrimon...|                 1|
# |Estrutura e Funçã...|                 1|
# |Arqueologia Brasi...|                 1|
# |Enfermagem da Fam...|                 1|
# |Introdução à Ciên...|                 1|
# | Viveiros Florestais|                 1|
# |      Epidemeiologia|                 1|
# |  Nutriçã de Animais|                 1|
# |Mineralogia e Cri...|                 1|
# |          Bioterismo|                 1|
# |Diversidade Anima...|                 1|
# |3ª Ciências Odont...|                 1|
# |Estagio Sup. em N...|                 1|
# |Fundamentação Teó...|                 1|
# |   Biologia Tecidual|                 1|
# |Projeto de Pesqui...|                 1|
# |Controle Dimensional|                 1|
# |         Palotologia|                 1|
# |Filosofia e Lógic...|                 1|
# |Histologia e Embr...|                 1|
# |      Psicopedagodia|                 1|
# |Endocrinologia Ap...|                 1|
# |Bases Epistemológ...|                 1|
# |    Exercicios 2 Ano|                 1|
# |Atencao Primaria ...|                 1|
# |   Livros Acadêmicos|                 1|
# |Família e Comunidade|                 1|
# |Dor Oro-facial e ...|                 1|
# |Av2 -  R Humanos ...|                 1|
# |Administração Fin...|                 1|
# |Corpo, Cultura e ...|                 1|
# |  Formação Econômica|                 1|
# |Biologia Molecula...|                 1|
# |        Larvicultura|                 1|
# |Análise de Sistem...|                 1|
# |   Artigos Jurídicos|                 1|
# |Direito das Empre...|                 1|
# |   Plano Museológico|                 1|
# |Gestão de Pessoas...|                 1|
# |     Física Acústica|                 1|
# |Introducao A Esta...|                 1|
# |Ética, Desenvolvi...|                 1|
# |Planejamento Esco...|                 1|
# |2.	distinga Efeit...|                 1|
# |Planejamento Part...|                 1|
# |Práticas Investig...|                 1|
# |               Adada|                 1|
# |Caderno de Questõ...|                 1|
# |Instalações Predi...|                 1|
# |Metodologia de Pe...|                 1|
# |Estratégias de Co...|                 1|
# |Projeto Republica...|                 1|
# |Matemática Financ...|                 1|
# |Modelos Probabilí...|                 1|
# |Biofísica para En...|                 1|
# |Informações Geren...|                 1|
# |Ocupação e Desenv...|                 1|
# |Prótese de Labora...|                 1|
# |Física do Ambient...|                 1|
# |Oficina de Matemá...|                 1|
# |            Estatuto|                 1|
# |Estágio Curricula...|                 1|
# |Fundamentos de Cá...|                 1|
# |Projeto de Sistem...|                 1|
# |Tecnologia em Res...|                 1|
# |         Instalações|                 1|
# |Ética Profissiona...|                 1|
# | Garantismo Jurídico|                 1|
# |Modelo de Requeri...|                 1|
# |Quimica Industrial I|                 1|
# |Ciclo de Vida Hum...|                 1|
# |Representação e A...|                 1|
# |Design de Superfí...|                 1|
# |His Econ Europeia...|                 1|
# |Biossegurança Apl...|                 1|
# |Conversão de Ener...|                 1|
# |Eletricidade e Te...|                 1|
# |       Desafio Enade|                 1|
# |Ergonomia Informa...|                 1|
# |Educação Inclusiv...|                 1|
# |Sistemas Veicular...|                 1|
# |    Direito do Idoso|                 1|
# |                 Eru|                 1|
# |Hospitalidade e T...|                 1|
# | Regencia 8 Semestre|                 1|
# |Dungeons And Dragons|                 1|
# |Legislação Portad...|                 1|
# |Composto Promocional|                 1|
# |Terapia em Alta C...|                 1|
# |  Controle Ambiental|                 1|
# |Tópicos Avançados...|                 1|
# |Oficina de Redaçã...|                 1|
# |Cont.met. e Prati...|                 1|
# |           Densidade|                 1|
# |Materiais e Tecno...|                 1|
# |  Pronto Atendimento|                 1|
# |Migrações Interna...|                 1|
# |Análise e Control...|                 1|
# |  As Matérias Online|                 1|
# |Tópicos em  Progr...|                 1|
# |Nascimento da Ant...|                 1|
# |Elaboração de Pro...|                 1|
# |Fim0430 - Física ...|                 1|
# |Democracia Partic...|                 1|
# | Líquidos Biológicos|                 1|
# |Narrativas Audivi...|                 1|
# | Matematica Concurso|                 1|
# |Direito Aplicado ...|                 1|
# |        Adm Produção|                 1|
# |Gestão Financeira...|                 1|
# |Canais de Distrib...|                 1|
# |História da Educa...|                 1|
# |     Programação Vba|                 1|
# |Introd A Ling Ing...|                 1|
# |  Hidrologia Geral I|                 1|
# |Métodos de Anális...|                 1|
# |Gestão Agroindust...|                 1|
# |  Gestação Finaceira|                 1|
# |Visao Estrategica...|                 1|
# |Automação da Manu...|                 1|
# |História e Futuro...|                 1|
# |   Ateliê de Projeto|                 1|
# |Subestações de Al...|                 1|
# |         Aprendizado|                 1|
# |Gestão Estratégic...|                 1|
# |  Treino em Pesquisa|                 1|
# |Metodologia de Lí...|                 1|
# |Admin de Serviço ...|                 1|
# |             Arabe I|                 1|
# |             Dp-pe I|                 1|
# |Tecnologias Educa...|                 1|
# |Seminário Interna...|                 1|
# |Exper de Qui para...|                 1|
# |Introdução A Enge...|                 1|
# |Controle de Quali...|                 1|
# |Processos Bioquím...|                 1|
# |Materiais Concret...|                 1|
# |  Nutrição Dietetica|                 1|
# |Logística e Cadei...|                 1|
# |Gestão de Materia...|                 1|
# |Psicologia Sócio-...|                 1|
# |Metodologia da Al...|                 1|
# |Adminstração da E...|                 1|
# |Métodos Computaci...|                 1|
# |Qualidade de Proc...|                 1|
# |Inferência Estatí...|                 1|
# |Ética e Normas da...|                 1|
# |Abrangência das A...|                 1|
# |História da Globa...|                 1|
# |Empreendedorismo ...|                 1|
# |Gestão do Desenvo...|                 1|
# |Filosofia, Sociol...|                 1|
# |Análise e Gestão ...|                 1|
# | Trabalho Científico|                 1|
# |História das Rela...|                 1|
# |Projeto Interdisc...|                 1|
# |Marketing Hospitalar|                 1|
# |Corrosão de Mater...|                 1|
# |Psicoterapia de G...|                 1|
# |Topicos em Odonto...|                 1|
# |Física Moderna e ...|                 1|
# |Fisiologia Endócr...|                 1|
# |#hipertrofia #sar...|                 1|
# |Pedologia e Físic...|                 1|
# |Gestão e Orçament...|                 1|
# |    Agronomia/ingles|                 1|
# |   A Revolucao Russa|                 1|
# |O Trabalho Psicop...|                 1|
# |Pi: Oficinas de E...|                 1|
# |Laboratório de Pr...|                 1|
# |Libras Intermediário|                 1|
# |Contabilidade e G...|                 1|
# |Ti - Tecnico em I...|                 1|
# |Geometria Quantit...|                 1|
# |Administração 5º ...|                 1|
# | Ciências Humanas II|                 1|
# |Clínica Odontológ...|                 1|
# |Culturas Brasileiras|                 1|
# |Adm de Compras e ...|                 1|
# |          Edificação|                 1|
# |Licenciatura em S...|                 1|
# |Comunicação Hormo...|                 1|
# |        Chocolataria|                 1|
# |              E.d.o.|                 1|
# |Política Educacio...|                 1|
# |Gestão da Qualida...|                 1|
# |Contribuições Soc...|                 1|
# |Resumo de Ciencia...|                 1|
# |Ecologia e Ecossi...|                 1|
# |Textos Fundamenta...|                 1|
# |Inovação e Criati...|                 1|
# |   Metodologia Geral|                 1|
# |Gerenciador de Ba...|                 1|
# |Planejamento e Ge...|                 1|
# |             Bromato|                 1|
# |Fundamentos de Mo...|                 1|
# |Projeto de Sinali...|                 1|
# |Praticas Laborato...|                 1|
# |Sociedade Civil n...|                 1|
# |          Banca Anac|                 1|
# |          Dicionário|                 1|
# |Sustentabilidade ...|                 1|
# |Engenharia e Sust...|                 1|
# |Ética Geral, Prof...|                 1|
# |Direito Penal, Ma...|                 1|
# |Equipamentos Elet...|                 1|
# |    Climatogeografia|                 1|
# |Avaliação Antropo...|                 1|
# |Enf e Parasito Ap...|                 1|
# |Estratégias Empre...|                 1|
# |Homem, Saúde e Me...|                 1|
# |Programação Estru...|                 1|
# |Introdução A Soft...|                 1|
# |Biotecnologia Bio...|                 1|
# |Crm/dbm/call Centers|                 1|
# |Noções de Direito...|                 1|
# |     Etologia Animal|                 1|
# |Perícia Forense  ...|                 1|
# |Abordagens Teóric...|                 1|
# |   Como Escrever Bem|                 1|
# |Cotidiano Escolar...|                 1|
# |Instituições de D...|                 1|
# |Listas de Exercíc...|                 1|
# |Lari - Laboratóri...|                 1|
# |História da Fotog...|                 1|
# |Técnicas Psicomét...|                 1|
# |Gameficação na Ed...|                 1|
# |Mecânica dos Sóli...|                 1|
# |Cálculo das Varia...|                 1|
# |História e Interd...|                 1|
# |Direito da Concor...|                 1|
# |A Língua Portugue...|                 1|
# |Teoria e Prática ...|                 1|
# |Habilidades Médic...|                 1|
# |Manual de Direito...|                 1|
# |Administração de ...|                 1|
# |Organometalicos e...|                 1|
# |Dicionário de Vet...|                 1|
# |     Webjornalismo I|                 1|
# |Planejamento e Ge...|                 1|
# |Avaliação do Dese...|                 1|
# |         Topologia I|                 1|
# |  Generos Academicos|                 1|
# |Ensino da Artes V...|                 1|
# |Material da Const...|                 1|
# |Implantodontia Bu...|                 1|
# |      Atelie Pro Arq|                 1|
# |     Direitos Humano|                 1|
# |Estudo de Utiliza...|                 1|
# |Informática - Mec...|                 1|
# |Transtornos do De...|                 1|
# |Estágio Supervis...|                 1|
# |Matemática e Ingl...|                 1|
# |Inteligencia Arti...|                 1|
# |Trabalho de Concl...|                 1|
# |Seminários e Proj...|                 1|
# |Fundamentos do Hu...|                 1|
# |Bases Teóricas e ...|                 1|
# |Estudos Críticos ...|                 1|
# |Química para Bioc...|                 1|
# |Integracao A Prat...|                 1|
# |Tópicos Especiais...|                 1|
# |Educação Matemáti...|                 1|
# |Simulador Empresa...|                 1|
# | Expressão em Volume|                 1|
# |Deveres, Proibiçõ...|                 1|
# |Fatores de Produç...|                 1|
# |Introdução Às Ins...|                 1|
# |  Educação e Turismo|                 1|
# |Tecnologia de Beb...|                 1|
# |Arbitragem e Perí...|                 1|
# |Climatologia Apli...|                 1|
# |Lógica e Fundamen...|                 1|
# |Teoria das Estrut...|                 1|
# |Iniciação à Vida ...|                 1|
# |  Patrimônio Público|                 1|
# |     Bioquimica Basi|                 1|
# |Enfermagem na Saú...|                 1|
# |Gestão de Transpo...|                 1|
# |Is - Corpo, Estig...|                 1|
# |Processamento de ...|                 1|
# |Oncologia Veterin...|                 1|
# |Prática Simulada ...|                 1|
# |Racionalidades Mé...|                 1|
# |Mapas Mentais - D...|                 1|
# | Controle Eletrônico|                 1|
# |       Arqueologia A|                 1|
# |Patologia Geral p...|                 1|
# |Programação de Má...|                 1|
# |Criatividade em P...|                 1|
# |   Instrumentalidade|                 1|
# |Técnicas Psicoter...|                 1|
# |Universidade Corp...|                 1|
# |Movimentos Sociai...|                 1|
# |Técnica de Prepar...|                 1|
# |Políticas Pública...|                 1|
# |Legislacao Societ...|                 1|
# |Planejamento e Ge...|                 1|
# |Fundamentos Filos...|                 1|
# |Atividade   Novo ...|                 1|
# |            Método I|                 1|
# |Direito da Infânc...|                 1|
# |Prática de Estági...|                 1|
# |Subestacoes de En...|                 1|
# |Comunicação e Mar...|                 1|
# |Segurança Interna...|                 1|
# |Principios Básico...|                 1|
# |Meios de Expressã...|                 1|
# |               A C O|                 1|
# |           Sorologia|                 1|
# |Filosofia das Cie...|                 1|
# |Introdução Aos Ma...|                 1|
# |Fundamento Biológico|                 1|
# |Projeto de Sistem...|                 1|
# |Dinâmica de Apren...|                 1|
# |Termodinâmica e T...|                 1|
# |Constituição dos ...|                 1|
# |Atividades em Pro...|                 1|
# |Estrutura e Funci...|                 1|
# |Ética e Deontolog...|                 1|
# |   Trabalho de Curso|                 1|
# |Práticas Fisioter...|                 1|
# |O Curso da Minha ...|                 1|
# |Teoria Geral da I...|                 1|
# |  Contexto Histórico|                 1|
# |  Analisa Matematica|                 1|
# |Neuropsi dos Proc...|                 1|
# |Psicologia da Vio...|                 1|
# |Estagio Supevisio...|                 1|
# |       Fluidotérmica|                 1|
# |Av1 - Ciê Con - S...|                 1|
# |   Cena e Tecnologia|                 1|
# |Semiologia e Prát...|                 1|
# |Fundamentos de Me...|                 1|
# |Agrostologia e Nu...|                 1|
# |Educação Especial...|                 1|
# |Acionamento Hidrá...|                 1|
# |Propedêutica e Pr...|                 1|
# |Seminários Integr...|                 1|
# |           Automatos|                 1|
# |Avaliando Aprend....|                 1|
# |            Pcn 2014|                 1|
# |Seminários de Est...|                 1|
# |Reprodução Assistida|                 1|
# |Fundamentos de Pr...|                 1|
# |Sociedade, Nature...|                 1|
# |Desenho Assistido...|                 1|
# |Sistemas de Aeron...|                 1|
# |Formas Farmacêuti...|                 1|
# |História da Fisio...|                 1|
# |Planejamento e De...|                 1|
# | Comunicação Escrita|                 1|
# |Zootecnia de Ovin...|                 1|
# |Linguística Histó...|                 1|
# |Gestão de Projeto...|                 1|
# |Matéria-prima par...|                 1|
# |     Ex:. Bucomaxilo|                 1|
# |Habilidades Profi...|                 1|
# |Tópicos em Histór...|                 1|
# |          Volumetria|                 1|
# |Anatomia Funciona...|                 1|
# |Design e Desenvol...|                 1|
# |Sistemática de Ex...|                 1|
# |     Mapa_conceitual|                 1|
# |Matemática e Quím...|                 1|
# |Atropologia e Cul...|                 1|
# | Urgencia Obstetrica|                 1|
# |Lavra de Minas A ...|                 1|
# |Deontologia e Leg...|                 1|
# |H. Moyses Nussenz...|                 1|
# |Código de Process...|                 1|
# | Psicoendocrinologia|                 1|
# |Matemática Comercial|                 1|
# |   Justiça Eleitoral|                 1|
# |Metodologia da Ge...|                 1|
# |Cultura, Comunica...|                 1|
# |      Controle Motor|                 1|
# |História e Cultur...|                 1|
# |    Biodiversidade I|                 1|
# |Saga A Fada de Ferro|                 1|
# |História da Ciênc...|                 1|
# |Retórica e Argume...|                 1|
# |Atenção Integral ...|                 1|
# |     Grego Moderno 1|                 1|
# |                   C|                 1|
# |Estágio Curricula...|                 1|
# | Modos de Transporte|                 1|
# |Metodologia e Açõ...|                 1|
# |Engenharia de Sis...|                 1|
# |Gestão do Conheci...|                 1|
# |          Tomografia|                 1|
# |Qsms - Qualidade,...|                 1|
# |Técnicas Corpórea...|                 1|
# |    Estudos da Forma|                 1|
# |Estudos Territori...|                 1|
# |Política Ambienta...|                 1|
# |Bioética e Formaç...|                 1|
# |Analise Instrumen...|                 1|
# |Oceanografia e Li...|                 1|
# |Ecologia na Agrop...|                 1|
# |             Credito|                 1|
# |  Geradores de Vapor|                 1|
# |Climatologia Agrí...|                 1|
# |Qualidade e Produ...|                 1|
# |Suporte Básico de...|                 1|
# |1897129 - Lic - F...|                 1|
# |Enfermagem na Org...|                 1|
# |           Game Arte|                 1|
# | Pedagogia das Lutas|                 1|
# |Urgencias e Emerg...|                 1|
# |Maternidade: Prev...|                 1|
# |Aspectos Históric...|                 1|
# |Laboratório de Lí...|                 1|
# |Direito - Reponsa...|                 1|
# |Politicas Pública...|                 1|
# |Relacoes Humanas ...|                 1|
# |Fisiopatologia do...|                 1|
# |The Classical The...|                 1|
# |Administração de ...|                 1|
# |Cirurgia Geral em...|                 1|
# |Pontes, Análise E...|                 1|
# |Física Geral e Ap...|                 1|
# | Serviço Social Unip|                 1|
# |         Gestão Ágil|                 1|
# |Tóp Gerais Ciênci...|                 1|
# |         Leis Penais|                 1|
# | Pesquisa Mineral II|                 1|
# |Fundamentos do Tr...|                 1|
# |Mamografia e Dens...|                 1|
# |Gestão de Estoque...|                 1|
# |História, Música ...|                 1|
# |Estudos Bíblicos ...|                 1|
# |Fundamentos do Tr...|                 1|
# |Pedagogia-ensino ...|                 1|
# |        Ecologia 6.0|                 1|
# |Formação de Reper...|                 1|
# |Bases do Tratamen...|                 1|
# |Física Termodinâm...|                 1|
# |Estágio na Educaç...|                 1|
# |   Politicas Publias|                 1|
# |Instituicoes de D...|                 1|
# |Literatura Popula...|                 1|
# | Projeto Integrado L|                 1|
# |Av2 de Psicologia...|                 1|
# ...
# |        Climatologia|               115|
# |Administração de ...|               115|
# |      Ética na Saúde|               115|
# |     Anatomia Dental|               116|
# |Portfólio Individual|               117|
# |       Periodontia I|               117|
# |Trabalho de Concl...|               118|
# |Planejamento Estr...|               118|
# |   Historia Antiga I|               118|
# |      Medicina Legal|               118|
# |Diagnóstico por I...|               119|
# |Fundamentos da Ad...|               119|
# |   Física - Mecânica|               119|
# |História da Educa...|               120|
# |           Pediatria|               120|
# |           Citologia|               120|
# |Metodologia do Tr...|               120|
# |     Nutrição Humana|               121|
# |   História Medieval|               121|
# |         Informática|               121|
# |Direito Civil e D...|               121|
# |Parasitologia Básica|               122|
# | Ciência do Ambiente|               123|
# |  Máquinas Elétricas|               123|
# |História do Brasil I|               124|
# |       Fitopatologia|               124|
# |          Radiologia|               126|
# |Acumulação Capita...|               126|
# |     Física Geral II|               127|
# |          Cálculo IV|               127|
# |            Estática|               127|
# |Leitura e Produçã...|               128|
# |Parasitologia Vet...|               128|
# |Gestão de Recurso...|               128|
# |Administração de ...|               129|
# |Psicologia da Edu...|               129|
# |      Gestão Pública|               129|
# |Fisioterapia em O...|               130|
# |Antropologia Cult...|               131|
# |Atividades Comple...|               133|
# |Português Instrum...|               134|
# |História da Améri...|               135|
# |           Cálculo A|               136|
# |      Saúde Coletiva|               136|
# |       Epidemiologia|               137|
# |    Direito Civil VI|               138|
# |Teoria das Estrut...|               138|
# |            Cirurgia|               138|
# |Anatomia dos Anim...|               138|
# |Geologia para Eng...|               138|
# |           Geografia|               139|
# |     Genética Humana|               139|
# |  Gestão de Projetos|               140|
# |Planejamento de C...|               140|
# |Circuitos Elétric...|               144|
# |   Gestão Financeira|               144|
# |     Psicofisiologia|               145|
# |      Bioestatística|               145|
# |Direito Empresari...|               145|
# |     Termodinâmica I|               145|
# |Sociologia Jurídi...|               145|
# |Introdução à Soci...|               146|
# |Literatura Brasil...|               146|
# |Teoria da Literat...|               146|
# |Alfabetização e L...|               147|
# |Contabilidade Ava...|               147|
# |           Concursos|               147|
# |  Nutrição Esportiva|               149|
# |Semiologia Veteri...|               149|
# |Termodinâmica Apl...|               150|
# |Inovação Tecnológica|               150|
# |Filosofia do Direito|               151|
# |Engenharia de Sof...|               151|
# |Psicologia do Des...|               151|
# |               Ética|               151|
# |Aspectos Antropol...|               152|
# |        Dentística I|               152|
# |    Produção Gráfica|               153|
# |Historiografia Br...|               153|
# |Histologia Veteri...|               154|
# |        Criminologia|               155|
# |Comportamento Org...|               156|
# |  Biologia Molecular|               157|
# |Mecânica dos Sólidos|               157|
# |Estudos Disciplin...|               157|
# |Teorias da Comuni...|               158|
# |    Gestão Ambiental|               158|
# |Treinamento e Des...|               161|
# |  Química Inorgânica|               161|
# |Direito Processua...|               162|
# |Sistematização do...|               162|
# |Programação Orien...|               162|
# |Geometria Descritiva|               163|
# |        Matemática I|               165|
# |          Hidrologia|               166|
# |Introdução ao Ser...|               167|
# |  Conforto Ambiental|               167|
# |  Modelagem de Dados|               169|
# |  Teoria da Historia|               169|
# |   Direito Ambiental|               169|
# |Probabilidade e E...|               170|
# | Materiais Elétricos|               171|
# |            Ecologia|               171|
# |Sistemas Estruturais|               171|
# |Direito Administr...|               172|
# |Anatomia Veterinária|               173|
# |        Bioquímica I|               174|
# |Estruturas de Con...|               175|
# |Eletrônica de Pot...|               175|
# |Administração Est...|               176|
# |Contabilidade Púb...|               176|
# |Fisioterapia Resp...|               177|
# |     Direito Civil V|               177|
# |              Libras|               177|
# |  Direito de Familia|               179|
# |         Anatomia II|               180|
# |   Economia Política|               180|
# |                 Oab|               181|
# |Equações Diferenc...|               181|
# |Direito do Consum...|               181|
# |            História|               181|
# |Geometria Analíti...|               182|
# |      Física Geral I|               183|
# |           Logística|               186|
# |   Lógica Matemática|               186|
# |    Ciências Sociais|               187|
# |       Neuroanatomia|               187|
# |  História da Arte I|               188|
# | Sociologia Jurídica|               189|
# |  Educação Ambiental|               189|
# | Fertilidade do Solo|               192|
# |       Programação I|               192|
# |Orçamento Empresa...|               193|
# |    Direito Penal IV|               194|
# |Administração da ...|               194|
# |Administração de ...|               194|
# |          Endodontia|               194|
# |Elementos de Máqu...|               196|
# |Sociologia da Edu...|               197|
# |Linguagem e Progr...|               197|
# |  Ética Profissional|               198|
# |Metodologia de Pe...|               199|
# |        Antropologia|               200|
# |           Urbanismo|               200|
# |   Matemática Básica|               200|
# |Fundamentos de Co...|               201|
# | Análise Estatística|               201|
# |Logística Interna...|               202|
# |              Inglês|               202|
# | Química Orgânica II|               204|
# |Teoria Geral do E...|               204|
# |Penal e Processo ...|               205|
# |Física Experiment...|               206|
# |Imunologia Veteri...|               210|
# |      Processo Penal|               212|
# |            Biologia|               215|
# |Comunicação nas E...|               215|
# |   Concreto Armado I|               216|
# |Introdução à Econ...|               217|
# |     Neurofisiologia|               217|
# |    Patologia Básica|               218|
# |História da Enfer...|               222|
# |      Banco de Dados|               222|
# |Direito Internaci...|               222|
# |    Direitos Humanos|               222|
# | Psicologia Jurídica|               225|
# | Anatomia Palpatória|               226|
# |   Física Teórica II|               227|
# |            Geologia|               228|
# |Direito Penal e P...|               229|
# |      Clínica Médica|               231|
# |      Anestesiologia|               236|
# |Desenho Arquitetô...|               238|
# |Inteligência Arti...|               239|
# |          Dentística|               241|
# |Análise Organizac...|               242|
# |   Semiologia Médica|               243|
# |Direito Processua...|               244|
# | Pesquisa de Mercado|               245|
# |    História da Arte|               246|
# |   Técnica Dietética|               250|
# |           Marketing|               251|
# |   Gestão de Pessoas|               253|
# |Fundamentos de Ma...|               255|
# |Nutrição e Dietética|               255|
# |Materiais de Cons...|               256|
# |    Física Teórica I|               260|
# |Anatomia Veteriná...|               261|
# |    Empreendedorismo|               261|
# |Análise das Demon...|               261|
# |Fundamentos de Si...|               262|
# |Matemática para N...|               264|
# |Contabilidade Com...|               264|
# |Qualidade de Soft...|               265|
# |Gestão da Cadeia ...|               265|
# |   Raciocínio Lógico|               265|
# |Modelagem de Sist...|               266|
# |Cálculo Diferenci...|               269|
# |      Serviço Social|               270|
# |Contabilidade Emp...|               271|
# |Lógica de Program...|               273|
# |Comunicação e Exp...|               274|
# |  Mercado Financeiro|               274|
# |  Física Teórica III|               275|
# |Ciência dos Mater...|               277|
# |Pesquisa Operacional|               279|
# |   Filosofia e Ética|               279|
# |Princípios da Ciê...|               281|
# |        Bromatologia|               283|
# |             Cálculo|               286|
# |Administração de ...|               287|
# |          Musculação|               293|
# |Teoria da Contabi...|               294|
# |Direito Processua...|               297|
# |Organização de Co...|               301|
# | Matemática Discreta|               302|
# |          Semiologia|               304|
# |   Anatomia Humana I|               305|
# | Direito do Trabalho|               308|
# |   Direito Penal III|               308|
# |Avaliação da Apre...|               313|
# |        Cinesiologia|               314|
# |Competências Gere...|               316|
# |Arquitetura e Urb...|               318|
# |Direito Previdenc...|               320|
# |Administração de ...|               321|
# |História da Psico...|               322|
# |Psicologia Aplica...|               323|
# |    Direito Civil IV|               324|
# |Estatística Aplicada|               325|
# |Eletricidade Apli...|               327|
# |          Enfermagem|               328|
# |Composição dos Al...|               328|
# |         Linguística|               329|
# |           Patologia|               340|
# |Conforto Ambiental I|               340|
# |Gerenciamento de ...|               346|
# |Direito Processua...|               349|
# |Ética e Responsab...|               354|
# |Anatomia e Escult...|               361|
# |           Fundações|               367|
# |Projeto Arquitetô...|               373|
# |Tópicos em Libras...|               374|
# |     Química Geral I|               379|
# |      Processo Civil|               386|
# |  Fisiologia Vegetal|               405|
# |          Sociologia|               409|
# |              Livros|               426|
# |           Português|               426|
# |      Psicopatologia|               428|
# |Psicologia da Per...|               441|
# |Avaliação Nutrici...|               444|
# |   Direito Civil III|               444|
# |       Macroeconomia|               451|
# |História da Educação|               452|
# |   Química Analítica|               453|
# |Introdução ao Dir...|               455|
# |Cálculo Vetorial ...|               456|
# |Circuitos Elétric...|               457|
# |Psicologia nas Or...|               457|
# |  Química Orgânica I|               457|
# | Direito Empresarial|               461|
# |Extras (livros, C...|               463|
# |Fundamentos da Ec...|               467|
# |       Parasitologia|               480|
# |Biologia Celular ...|               486|
# |          Anatomia I|               488|
# |    Eletromagnetismo|               491|
# |Linguagem de Prog...|               492|
# |              Física|               501|
# |   Imunologia Basica|               510|
# |      Físico-química|               517|
# |Processos Psicolo...|               517|
# |          Matemática|               532|
# |         Estatística|               533|
# |Análise Experimen...|               537|
# |          Algoritmos|               540|
# |            Economia|               551|
# |             Química|               556|
# |Planejamento de C...|               559|
# |Cinesiologia e Bi...|               565|
# |Anatomia do Apare...|               571|
# |          Hidráulica|               577|
# |  Direito Tributário|               578|
# |      Cinesioterapia|               579|
# |Probabilidade e E...|               580|
# | Gestão de Processos|               585|
# |Direito Constituc...|               594|
# |Sistemas Operacio...|               612|
# |Filosofia da Educ...|               628|
# |   Educação Especial|               628|
# |Legislação Tribut...|               630|
# |            Nutrição|               639|
# |  Estrutura de Dados|               656|
# |Resistência dos M...|               672|
# |  Anatomia Sistêmica|               673|
# |  Mecânica dos Solos|               675|
# |Fundamentos das C...|               684|
# |    Direito Civil II|               686|
# |     Educação Física|               702|
# |         Psicanálise|               708|
# |Redes de Computad...|               719|
# |       Microeconomia|               731|
# |Fenômenos dos Tra...|               734|
# |            Anatomia|               748|
# |Contabilidade Ger...|               770|
# |     Desenho Técnico|               784|
# |Direito Processua...|               793|
# | Gestão da Qualidade|               793|
# |         Cálculo III|               793|
# |Teorias Psicanalí...|               796|
# |     Patologia Geral|               807|
# |   Psicologia Social|               815|
# |   Língua Portuguesa|               846|
# |             Direito|               856|
# |Psicologia na Edu...|               862|
# |          Topografia|               881|
# |           Biofísica|               885|
# |           Filosofia|               890|
# |          Fisiologia|               896|
# |Teoria Geral da A...|               941|
# |       Termodinâmica|               950|
# |Fisiologia do Exe...|               961|
# |         Embriologia|               967|
# |          Física III|               970|
# |História do Direi...|               972|
# |Resistência dos M...|              1000|
# |Teoria Geral do P...|              1018|
# |           Pedagogia|              1045|
# |          Histologia|              1065|
# |            Didática|              1105|
# |    Química Orgânica|              1109|
# | História do Direito|              1112|
# |     Análise Textual|              1141|
# |       Direito Civil|              1223|
# |          Psicologia|              1248|
# | Contabilidade Geral|              1273|
# |           Física II|              1294|
# |Introdução ao Est...|              1296|
# |Histologia e Embr...|              1317|
# |    Cálculo Numérico|              1319|
# |Mecânica dos Fluidos|              1350|
# |       Microbiologia|              1371|
# |Contabilidade de ...|              1510|
# |    Direito Penal II|              1519|
# |Contabilidade Básica|              1542|
# |Direito Administr...|              1548|
# | Geometria Analítica|              1581|
# |Cálculo Diferenci...|              1595|
# |Administração Fin...|              1613|
# |      Álgebra Linear|              1623|
# |Contabilidade / C...|              1678|
# |       Química Geral|              1701|
# |          Imunologia|              1739|
# |       Direito Penal|              1822|
# |Introdução à Admi...|              1918|
# |    Ciência Política|              1973|
# |    Biologia Celular|              1978|
# |Direito do Trabal...|              1998|
# |Direito Administr...|              2075|
# |     Direito Civil I|              2087|
# |       Administração|              2128|
# |Metodologia Cient...|              2135|
# |      Mecânica Geral|              2147|
# |        Farmacologia|              2240|
# |            Genética|              2275|
# |Resistência dos M...|              2365|
# |Cálculo Diferenci...|              2457|
# |          Cálculo II|              2537|
# |Direito Processua...|              2574|
# |                null|              2693|
# |Direito Constituc...|              2857|
# |   Fisiologia Humana|              2906|
# |     Direito Penal I|              2956|
# |            Física I|              3023|
# |Matemática Financ...|              3405|
# |Direito Constituc...|              3926|
# |     Anatomia Humana|              3950|
# |           Cálculo I|              4053|
# +--------------------+------------------+
# only showing top 20580 rows

# %%
#Total de sessões de cada aluno por plataforma 
df = df_final.groupBy("Id", df_final.StudentClientSession).agg(countDistinct("SessionStartTime")).show()
# Out:
# +--------------------+--------------------+--------------------------------+
# |                  Id|StudentClientSession|count(DISTINCT SessionStartTime)|
# +--------------------+--------------------+--------------------------------+
# |ca3889a8e8de284bc...|                 iOS|                              15|
# |c00985ba97a7c689c...|             Website|                               2|
# |4cffc6a291cc9fb34...|             Website|                               7|
# |2803c8592434ffc04...|             Website|                               2|
# |1602fce5d5d84f19f...|                 iOS|                             150|
# |7e88909913fe8d358...|             Website|                               7|
# |7f4b11f1b380ca821...|                 iOS|                              39|
# |fc0cc3ecfa0cc8f93...|             Android|                              26|
# |ac3d184258e417dda...|             Website|                               2|
# |40b5a5f04d84b3c05...|             Website|                               2|
# |b9cfa043bd304ef49...|             Android|                               7|
# |add3ccf3e25a63869...|             Android|                              11|
# |acc6ae9e0937b6348...|             Android|                               5|
# |12a87a353aad29617...|             Website|                               8|
# |f4d839d74b16bb79c...|             Website|                               4|
# |6d98f3b2eca38d982...|             Website|                              12|
# |6d9f83ca8eac73ede...|             Website|                              16|
# |3f134144ee6351640...|             Website|                               1|
# |7c8f33486d832bcd9...|             Website|                              17|
# |1f59d048f8e27b1d2...|             Android|                               4|
# +--------------------+--------------------+--------------------------------+
# only showing top 20 rows

# %%
#Sessão por estudante 
df = df_final.groupBy("StudentClientSession").agg(countDistinct("Id")).show()
# Out:
# +--------------------+------------------+
# |StudentClientSession|count(DISTINCT Id)|
# +--------------------+------------------+
# |              Webapp|              6707|
# |                 iOS|              3291|
# |             Website|             47795|
# |             Android|             13564|
# +--------------------+------------------+

# %%
#Estudantes por estado
df = df_final.groupBy("State").agg(countDistinct("Id")).show()
# Out:
# +-------------------+------------------+
# |              State|count(DISTINCT Id)|
# +-------------------+------------------+
# |     Santa Catarina|               876|
# | Mato Grosso do Sul|               421|
# |              Goiás|               815|
# |        Mato Grosso|               265|
# |               null|             35393|
# |              Ceará|              1236|
# |     Espírito Santo|               595|
# |              Piauí|               282|
# |             Paraná|              1438|
# |            Alagoas|               331|
# |              Bahia|              1354|
# |            Roraima|                59|
# |   Distrito Federal|               385|
# |         Pernambuco|               954|
# |           Amazonas|               342|
# |  Rio Grande do Sul|              1192|
# |               Acre|                53|
# |Rio Grande do Norte|               367|
# |            Sergipe|               427|
# |          São Paulo|              3870|
# +-------------------+------------------+
# only showing top 20 rows

# %%
#Alunos por Universidade
df = df_final.groupBy("UniversityName").agg(countDistinct("Id")).show()
# Out:
# +-----------------+------------------+
# |   UniversityName|count(DISTINCT Id)|
# +-----------------+------------------+
# |            UFABC|                56|
# |             IFTO|                18|
# |             FJAV|                 4|
# |         UNIVILLE|                36|
# |             ESUV|                 6|
# |             IEST|                 2|
# |UNINASSAU CARUARU|                17|
# |            ASSER|                 4|
# |             FSJT|                11|
# |            FAEDA|                 1|
# |           IMESSM|                 1|
# |             FACH|                 1|
# |         FACDELTA|                 5|
# |             IFRJ|                50|
# |            CEULP|                40|
# |              FDC|                 4|
# |             UEZO|                13|
# |              AMF|                 4|
# |     Faculdade JK|                 3|
# |           ISETED|                 1|
# +-----------------+------------------+
# only showing top 20 rows

# %%
#Alunos por tipo de plano
df = df_final.groupBy('PlanType').agg(countDistinct("Id")).show()
# Out:
# +--------+------------------+
# |PlanType|count(DISTINCT Id)|
# +--------+------------------+
# |    null|             59203|
# |  Mensal|               737|
# |   Anual|                60|
# +--------+------------------+

# %%
#Escrevendo arquivo parquet tratado
df_final.write.parquet('C:\\Users\\dbello\Documents\\pd-desafio\\refined_data\\baseA')
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pyspark\sql\utils.py in deco(*a, **kw)
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\py4j\protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     327                     "An error occurred while calling {0}{1}{2}.\n".
# --> 328                     format(target_id, ".", name), value)
#     329             else:
#
# Py4JJavaError: An error occurred while calling o339.parquet.
# : org.apache.spark.sql.AnalysisException: path file:/C:/Users/dbello/Documents/pd-desafio/refined_data/baseA already exists.;
# 	at org.apache.spark.sql.execution.datasources.InsertIntoHadoopFsRelationCommand.run(InsertIntoHadoopFsRelationCommand.scala:114)
# 	at org.apache.spark.sql.execution.command.DataWritingCommandExec.sideEffectResult$lzycompute(commands.scala:104)
# 	at org.apache.spark.sql.execution.command.DataWritingCommandExec.sideEffectResult(commands.scala:102)
# 	at org.apache.spark.sql.execution.command.DataWritingCommandExec.doExecute(commands.scala:122)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$execute$1.apply(SparkPlan.scala:131)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$execute$1.apply(SparkPlan.scala:127)
# 	at org.apache.spark.sql.execution.SparkPlan$$anonfun$executeQuery$1.apply(SparkPlan.scala:155)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:151)
# 	at org.apache.spark.sql.execution.SparkPlan.executeQuery(SparkPlan.scala:152)
# 	at org.apache.spark.sql.execution.SparkPlan.execute(SparkPlan.scala:127)
# 	at org.apache.spark.sql.execution.QueryExecution.toRdd$lzycompute(QueryExecution.scala:80)
# 	at org.apache.spark.sql.execution.QueryExecution.toRdd(QueryExecution.scala:80)
# 	at org.apache.spark.sql.DataFrameWriter$$anonfun$runCommand$1.apply(DataFrameWriter.scala:676)
# 	at org.apache.spark.sql.DataFrameWriter$$anonfun$runCommand$1.apply(DataFrameWriter.scala:676)
# 	at org.apache.spark.sql.execution.SQLExecution$$anonfun$withNewExecutionId$1.apply(SQLExecution.scala:78)
# 	at org.apache.spark.sql.execution.SQLExecution$.withSQLConfPropagated(SQLExecution.scala:125)
# 	at org.apache.spark.sql.execution.SQLExecution$.withNewExecutionId(SQLExecution.scala:73)
# 	at org.apache.spark.sql.DataFrameWriter.runCommand(DataFrameWriter.scala:676)
# 	at org.apache.spark.sql.DataFrameWriter.saveToV1Source(DataFrameWriter.scala:285)
# 	at org.apache.spark.sql.DataFrameWriter.save(DataFrameWriter.scala:271)
# 	at org.apache.spark.sql.DataFrameWriter.save(DataFrameWriter.scala:229)
# 	at org.apache.spark.sql.DataFrameWriter.parquet(DataFrameWriter.scala:566)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(Unknown Source)
# 	at java.lang.reflect.Method.invoke(Unknown Source)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:282)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:238)
# 	at java.lang.Thread.run(Unknown Source)
#
#
# During handling of the above exception, another exception occurred:
#
# AnalysisException                         Traceback (most recent call last)
# <ipython-input-29-d285ca660deb> in <module>
# ----> 1 df_final.write.parquet('C:\\Users\\dbello\Documents\\pd-desafio\\refined_data\\baseA')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pyspark\sql\readwriter.py in parquet(self, path, mode, partitionBy, compression)
#     841             self.partitionBy(partitionBy)
#     842         self._set_opts(compression=compression)
# --> 843         self._jwrite.parquet(path)
#     844
#     845     @since(1.6)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\py4j\java_gateway.py in __call__(self, *args)
#    1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
# -> 1257             answer, self.gateway_client, self.target_id, self.name)
#    1258
#    1259         for temp_arg in temp_args:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pyspark\sql\utils.py in deco(*a, **kw)
#      67                                              e.java_exception.getStackTrace()))
#      68             if s.startswith('org.apache.spark.sql.AnalysisException: '):
# ---> 69                 raise AnalysisException(s.split(': ', 1)[1], stackTrace)
#      70             if s.startswith('org.apache.spark.sql.catalyst.analysis'):
#      71                 raise AnalysisException(s.split(': ', 1)[1], stackTrace)
#
# AnalysisException: 'path file:/C:/Users/dbello/Documents/pd-desafio/refined_data/baseA already exists.;'
